# %%
# !git clone https://github.com/di-dimitrov/mmf.git

# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# %cd /content/mmf
# !pip install --editable .

# %%
### DATA PREPARATION
# !mkdir -p /root/.cache/torch/mmf/data/
# !cp -r /content/mmf/data/. /root/.cache/torch/mmf/data/

# %%
#Remove Useless files
# !rm -rf /usr/local/lib/python2.7 /swift /usr/local/cuda-10.0 /tensorflow-1.15.2/ /content/sample_data/

# %%
# !mmf_run config=./projects/memes_binary/configs/visual_bert/from_coco.yaml \
datasets=memes_binary \
model=visual_bert

# %%
# !mmf_run config=./projects/memes_binary/configs/vilbert/from_cc.yaml \
datasets=memes_binary \
model=vilbert

# %%
# !mmf_run config=./projects/memes/configs/visual_bert/from_coco.yaml \
datasets=memes \
model=visual_bert \

# %%
# !mmf_run config=./projects/memes/configs/vilbert/from_cc.yaml \
datasets=memes \
model=vilbert

# %%
# !mmf_run config=./projects/memes_tgt/configs/visual_bert/from_coco.yaml \
datasets=memes_tgt \
model=visual_bert

# %%
# !mmf_run config=./projects/memes_tgt/configs/vilbert/from_cc.yaml \
datasets=memes_tgt \
model=vilbert
